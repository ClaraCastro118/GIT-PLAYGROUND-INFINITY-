# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaraCastro118/GIT-PLAYGROUND-INFINITY-/blob/main/Aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# operadores condicionais

# %%
# SE - if ( uma determinada condicao for verdadeira)
#    executa a tarefa (linha)

# %%
if 5 > 3:
  print("5 é maior que 3")
# Out:
# 5 é maior que 3

# %%
if 5 < 3:
  print("5 é maior que 3")

# %%
# SE - if ( uma determinada condicao for verdadeira)
#    executa a tarefa (linha)
# SENAO - else
#     essa linha sera executada

# %%
if 5 < 3:
  print("5 é maior que 3")
else:
  print("5 não é maior que 3")
# Out:
# 5 não é maior que 3

# %%
n = 9

if n == 4 :
  print("n é igual a 4")
else:
  if n == 3:
    print("n é igual a 3 ")
  else:
    if n == 9:
      print("n é igual a 9")
    else:
      print(" n é um valor desconhecido")
# Out:
# n é igual a 9

# %%
n = 1

if n == 4 :
  print("n é igual a 4")
elif n == 3:
    print("n é igual a 3 ")
elif n == 9:
      print("n é igual a 9")
else:
      print(" n é um valor desconhecido")
# Out:
#  n é um valor desconhecido

# %%
x = 1
y = 5

if (x >1) and (y % 2 == 0):
 print("X maior que 1 e y é par ")

# %%
x = 2
y = 5

if (x >1) and (y % 2 == 0):
 print("X maior que 1 e y é par ")

# %%
x = 1
y = 6

if (x >1) and (y % 2 == 0):
 print("X maior que 1 e y é par ")

# %%
x = 2
y = 6

if (x >1) and (y % 2 == 0):
 print("X maior que 1 e y é par ")
# Out:
# X maior que 1 e y é par

# %%
x = 1
y = 4

if (x >1) and (y % 2 == 0):
 print("X maior que 1 e y é par ")
else:
  print("uma ou nenhuma das condições foram satisfeitas ")
# Out:
# uma ou nenhuma das condições foram satisfeitas

# %%
x = 1
y = 4

if (x >1) or (y % 2 == 0):
 print("X maior que 1 e y é par ")
else:
  print("uma ou nenhuma das condições foram satisfeitas ")
# Out:
# X maior que 1 e y é par

# %% [markdown]
# #Exercício
#
# 1. Leia a idade do usuário e classifique-o em:
# - Criança – 0 a 12 anos
# - Adolescente – 13 a 17 anos
# - Adulto – acima de 18 anos
# -Se o usuário digitar um número negativo, mostrar a mensagem que a idade é inválida
#
#
#
# 2. Calcular a média de um aluno que cursou a disciplina de Programação I, a partir da leitura das notas M1, M2 e M3; passando por um cálculo da média aritmética. Após a média calculada, devemos anunciar se o aluno foi aprovado, reprovado ou pegou exame
# - Se a média estiver entre 0.0 e 4.0, o aluno está reprovado
# - Se a média estiver entre 4.1 e 6.0, o aluno pegou exame
# - Se a média for maior do que 6.0, o aluno está aprovado
# - Se o aluno pegou exame, deve ser lida a nota do exame. Se a nota do exame for maior do que 6.0, está aprovado, senão; está reprovado

# %%
#resultado do exercicio

#questao 01

idade = int(input("Digite a idade: "))

if idade <= 12 :
    print("criança")
elif idade <= 17:
    print("adolescente")
else:
    print("Adulto")
# Out:
# Digite a idade: 14
# adolescente

# %%
#correcao exercicio 01


idade = int(input("Digite a idade: "))

if idade >= 0 and idade <12 :
    print("Criança")
elif idade >= 12 and idade <18:
    print("Adolescente")
elif idade >= 18:
    print("Adulto")
else:
    print("Idade inválida")

# %%
#questao 02


Media1 = float(input("Digite a nota Media1: "))
Media2 = float(input("Digite a nota Media2: "))
Media3 = float(input("Digite a nota Media3: "))

media = (Media1 + Media2 + Media3) / 3
media = round(media, 2)

print("Média:", media)

if  media <= 4.0:
    print("Reprovado")
elif media <= 6.0:
    print("Exame")
    nota_exame = float(input("Digite a nota do exame: "))

    if nota_exame > 6.0:
        print("Aprovado no exame")
    else:
        print("Reprovado no exame")
else:
    print("Aprovado")

# %%
#correcao questao 02
m1 = float(input("Digite a nota M1: "))
m2 = float(input("Digite a nota M2: "))
m3 = float(input("Digite a nota M3: "))
# Out:
# Digite a nota M1: 8
# Digite a nota M2: 7
# Digite a nota M3: 5

# %%
#correcao questao 02

media = (m1 + m2 + m3) /3

print("Média:", media)

# %%
#correcao questao 02

if media >= 0.0 and media <= 4.0:
  print("Reprovado")
elif media >= 4.1 and media <= 6.0:
  print("Está de RECUPERÇÂo")

  exame = float(input("Digite a nota do exame: "))
  if exame >= 6.0:
    print("Aprovado no exame")
  else:
    print("Reprovado no exame")

else:
  print("Aprovado")
# Out:
# Está de RECUPERÇÂo
# Digite a nota do exame: 7
# Aprovado no exame

# %% [markdown]
# estrutura de repetição FOR

# %%
print(1)
print(2)
print(3)
print(4)
print(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# for

for numero in range(1, 6):
  print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for num in range(1, 6 ,1):
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for num in range(5,0,-1):
  print(num)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
5+4+3+2+1
# Out:
# 15

# %%
soma = 0
for num in range (1,6):
  soma = soma + num
print(soma)
# Out:
# 15

# %%
soma = 0
for num in range (1,101):
  soma = soma + num
print(soma)
# Out:
# 5050

# %%
palavra = "sorvete"
for letra in palavra:
  print(letra)
# Out:
# s
# o
# r
# v
# e
# t
# e

# %%
#for aninhado for dentro do for

for i in range (0,5):
  print(i)
  print("----")
# Out:
# 0
# ----
# 1
# ----
# 2
# ----
# 3
# ----
# 4
# ----

# %%
for i in range (0,5):
  print(i)
  print("----")
  for j in range(0,3):
    print(j)
  print("----")
# Out:
# 0
# ----
# 0
# 1
# 2
# ----
# 1
# ----
# 0
# 1
# 2
# ----
# 2
# ----
# 0
# 1
# 2
# ----
# 3
# ----
# 0
# 1
# 2
# ----
# 4
# ----
# 0
# 1
# 2
# ----

# %%
#estrutura de repeticao WHILE

numero = 1
while numero <6:
  print(numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
numero = 5
while numero > 0:
  print(numero)
  numero = numero -1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
soma = 0
numero = 1
while numero < 6:
  soma = soma + numero
  numero = numero + 1
print(soma)
# Out:
# 15

# %%
#pedindo um numero ao usuario


numero = 12
while numero < 1 or numero > 10:
  numero = int(input("Digite um numero de 1 a 10: "))
print("Obrigado")

# %%
# 2. Imprimir a tabuada do número 3
# Ex.:
# 3 x 1 = 3;
# 3 x 2 = 6;
# 3 x 3 = 9
#  ...
# 3 x 10 = 30.


#usando o for

for i in range (1,11):
  print("3 x", i, "=", 3*i)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
#correcao com o professor
for i in range (1,11):
  print("3 x {} = {}".format (i,3*1))
# Out:
# 3 x 1 = 3
# 3 x 2 = 3
# 3 x 3 = 3
# 3 x 4 = 3
# 3 x 5 = 3
# 3 x 6 = 3
# 3 x 7 = 3
# 3 x 8 = 3
# 3 x 9 = 3
# 3 x 10 = 3

# %%
# Ler 5 notas e informar a média

nota = media = soma = 0
print(nota,media,soma)

# for _ in range(1,6):
#   nota = float(input(f"Digite a nota: "))

for i in range(1,6):
  nota = float(input(f"Digite a nota {i}: "))
  soma = soma + nota
media = soma / 5
print("Média:", media)
# Out:
# 0 0 0
# Digite a nota 1: 5
# Digite a nota 2: 7
# Digite a nota 3: 8
# Digite a nota 4: 9
# Digite a nota 5: 4
# Média: 6.6

# %%
#com while

nota = soma = 0
numero = 1
while numero <= 5 :
  nota = float(input(f"Digite a nota {numero}: "))
  soma = soma + nota
  numero = numero + 1
media = soma / 5
print("Média:", media)
# Out:
# Digite a nota 1: 4
# Digite a nota 2: 8
# Digite a nota 3: 7
# Digite a nota 4: 9
# Digite a nota 5: 2
# Média: 6.0

# %%
i = 1
while i <= 10:
  print("3 x", i , "=", 3 *i)
  i += 1
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
# Tabuada do 3 usando while
numero = 3


while numero <= 10:
    print ("3 x {} = {}". format(numero, 3*numero))
    numero += 1
# Out:
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
